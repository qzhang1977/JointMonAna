# %%
#FailureRate = 0.01, M/N = 0.1, FaultRecoverDelay = 9.498082224619441
#FailureRate = 0.01, M/N = 0.5, FaultRecoverDelay = 7.512383158903891
#FailureRate = 0.01, M/N = 0.8, FaultRecoverDelay = 5.993790680030348
#FailureRate = 0.08, M/N = 0.1, FaultRecoverDelay = 9.498393368425
#FailureRate = 0.08, M/N = 0.5, FaultRecoverDelay = 7.501069025274008
#FailureRate = 0.08, M/N = 0.8, FaultRecoverDelay = 6.004318493253448
#FailureRate = 0.3, M/N = 0.1, FaultRecoverDelay = 9.501766504201154
#FailureRate = 0.3, M/N = 0.5, FaultRecoverDelay = 7.501212979143424
#FailureRate = 0.3, M/N = 0.8, FaultRecoverDelay = 5.99970141852858


import matplotlib.pyplot as plt
x = [0.01, 0.08, 0.3]
y1 = [9.498082224619441, 9.498393368425, 9.501766504201154]
y2 = [7.51238315890389,  7.501069025274008, 7.501212979143424]
y3 = [5.993790680030348, 6.004318493253448, 5.99970141852858]

#pt.plot(x, y1, 'r--', x, y2, 'b--', x, y3, 'g--')
plt.ylabel('Delay')
plt.xlabel('FailureRate')

line1, = plt.plot(y1, label="M/N = 0.1", linestyle='--')
line2, = plt.plot(y2, label="M/N = 0.5", linestyle='--')
line3, = plt.plot(y3, label="M/N = 0.8", linestyle='--')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


plt.show()
